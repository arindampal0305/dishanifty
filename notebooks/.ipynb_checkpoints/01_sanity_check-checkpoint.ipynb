# %%
import pandas as pd

df = pd.read_csv("../data/processed/nifty50_labeled.csv", index_col=0, parse_dates=True)

print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nDate range:", df.index.min(), "to", df.index.max())
print("\nNull values:\n", df.isnull().sum())
print("\nClass distribution:")
print(df['Target'].value_counts())
print(df['Target'].value_counts(normalize=True).round(3))
# Out:
# Shape: (2658, 24)
#
# Columns: ['Close', 'High', 'Low', 'Open', 'Volume', 'Return', 'Volatility_10', 'SMA_10', 'SMA_20', 'SMA_50', 'EMA_10', 'EMA_20', 'EMA_50', 'RSI_14', 'MACD', 'MACD_Signal', 'BB_Upper', 'BB_Lower', 'BB_Middle', 'BB_Width', 'ATR_14', 'Momentum_10', 'Next_Return', 'Target']
#
# Date range: 2015-03-17 00:00:00 to 2025-12-30 00:00:00
#
# Null values:
#  Close            0
# High             0
# Low              0
# Open             0
# Volume           0
# Return           0
# Volatility_10    0
# SMA_10           0
# SMA_20           0
# SMA_50           0
# EMA_10           0
# EMA_20           0
# EMA_50           0
# RSI_14           0
# MACD             0
# MACD_Signal      0
# BB_Upper         0
# BB_Lower         0
# BB_Middle        0
# BB_Width         0
# ATR_14           0
# Momentum_10      0
# Next_Return      0
# Target           0
# dtype: int64
#
# Class distribution:
# Target
# 2    1063
# 0     869
# 1     726
# Name: count, dtype: int64
# Target
# 2    0.400
# 0    0.327
# 1    0.273
# Name: proportion, dtype: float64
